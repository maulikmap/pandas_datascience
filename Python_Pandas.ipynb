# %% [markdown]
# <a href="https://colab.research.google.com/github/maulikmap/pandas_datascience/blob/main/Python_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ***Python Data Handling using Pandas***

# %% [markdown]
# # **Section - 1 : Introduction to Pandas in Python**

# %% [markdown]
# ***Why Pandas is used for Data Science?***
#
# *   Pandas is built on the top of the NumPy library which means that a lot of structures of NumPy are used or replicated in Pandas.
# *   The data produced by Pandas are often used as input for plotting functions of Matplotlib, statistical analysis in SciPy, machine learning algorithms in Scikit-learn.
# *   Pandas program can be run from any text editor but it is recommended to use Jupyter Notebook.
# *   Jupyter given the ability to execute code in a particular cell rather than executing the entire file.
# *   Jupyter also provides an easy way to visualize pandas data frames and plots.

# %% [markdown]
# ***Introduction to Pandas in Python***
#
# Pandas is an open-source library that is made mainly for working with relational or labeled data both easily and intuitively. It provides various data structures and operations for manipulating numerical data and time series. This library is built on top of the **NumPy library**. Pandas is fast and it has high performance & productivity for users.
#
# ***Advantages***
# *   Fast and efficient for manipulating and analyzing data.
# *   Data from different file objects can be loaded.
# *   Easy handling of missing data (represented as NaN) in floating point as well as non-floating point data.
# *   Size mutability: columns can be inserted and deleted from DataFrame and higher dimensional objects.
# *   Data set merging and joining.
# *   Flexible reshaping and pivoting of data sets
# *   Provides time-series functionality.
# *   Powerful group by functionality for performing split-apply-combine operations on data sets.

# %% [markdown]
# ***Getting Started***

# %% [markdown]
# **Installation of Pandas**

# %% [markdown]
# In google Colab, We don't require to install Pandas separately. **It is pre-installed here.**
#
# But, In standalone system you can install it using this command:
#
# **Pandas can be installed via pip from PyPI.**
#
# **>pip install pandas**
#
# ***Working with conda?***
#
# pandas is part of the Anaconda distribution and can be installed with Anaconda or Miniconda:
#
# ***>conda install pandas***

# %% [markdown]
# **How to check the Version of pandas?**

# %%
import pandas

print (pandas.__version__)
# Out:
# 1.3.5

# %% [markdown]
# **import Pandas as pd**
#
# Pandas is usually imported under the **pd alias**.
#
# **What is alias**:  In Python alias are an alternate name for referring to the same thing.

# %%
import pandas as pd

# %% [markdown]
# **Pandas generally provide following two data structures for manipulating data:**
#
# *   Series
# *   DataFrame

# %% [markdown]
# ***Series is like a column, a DataFrame is the whole table.***

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **DataFrames**
#
# *   A Data frame is a two-dimensional data structure, i.e., data is aligned in a tabular fashion in rows and columns.
# *   Pandas DataFrame consists of three principal components, the data, rows, and columns.
# *   Data sets in Pandas are usually **multi-dimensional tables**, called DataFrames.

# %%
import pandas as pd

data = {
    'apples' : ['3','2','0','1'],
    'orange' : ['0','3','7','2']
}

df = pd.DataFrame(data)

print(df)
# Out:
#   apples orange
# 0      3      0
# 1      2      3
# 2      0      7
# 3      1      2

# %%
import pandas

car_data = {
    'cars' : ["BMW", "Maruti", "Kia", "Tatamotor"],
    'Models' : ['x7', 'xl6', 'Saltos', 'Nexon'],
    'price' : ['5000000', '1000000', '1200000', '1050000']

}

#load data into a DataFrame object:
df = pandas.DataFrame(car_data)

print(df)
# Out:
#         cars  Models    price
# 0        BMW      x7  5000000
# 1     Maruti     xl6  1000000
# 2        Kia  Saltos  1200000
# 3  Tatamotor   Nexon  1050000

# %%
import pandas as pd

student_data = {
    'Student' : ["Maths", "Physics", "Chemestry", "Biology", "English", "Hindi"],
    'Marks' : [95,84,76,87,65,68]
}

df = pd.DataFrame(student_data)

print(df)
# Out:
#      Student  Marks
# 0      Maths     95
# 1    Physics     84
# 2  Chemestry     76
# 3    Biology     87
# 4    English     65
# 5      Hindi     68

# %% [markdown]
# **Pandas Series**
#
# **What is a Series?**
#
# *   Pandas Series is a one-dimensional labelled array capable of holding data of any type (integer, string, float, python objects, etc.).
# *   The axis labels are collectively called indexes.
# *   Pandas Series is nothing but a column in an excel sheet.
# *   Labels need not be unique.
# *   A Pandas Series is like a column in a table.

# %% [markdown]
# ***Creating a Series***
# *   In the real world, a Pandas Series will be created by loading the datasets from existing storage, storage can be SQL Database, CSV file or an Excel file.
# *   Pandas Series can also be created from the lists, dictionary, and from a scalar value etc.

# %%
import pandas as pd

a = [1,7,3,4]

ser = pd.Series(a)

print(ser)
# Out:
# 0    1
# 1    7
# 2    3
# 3    4
# dtype: int64

# %% [markdown]
# **Labels**
#
# The values are labeled with their index number by default. First value has index 0, second value has index 1 etc.
#
# This label can be used to access a specified value.

# %%
print(ser[0])
# Out:
# 1

# %% [markdown]
# **Create Labels**
#
# **Name your own labels**

# %%
import pandas as pd

a = [2,1,4]

ser = pd.Series(a, index = ["X","Y","Z"])

print(ser)
# Out:
# X    2
# Y    1
# Z    4
# dtype: int64

# %% [markdown]
# Access the variable with it's index

# %%
print(ser["Y"])
# Out:
# 1

# %% [markdown]
# **Key/Value Objects as Series**
#
# You can also use a key/value object, like a dictionary, when creating a Series.

# %%
import pandas as pd

cust_bal = {"Custumer-1": 1000, "Custumer-2": 1200, "Custumer-3": 2500}

srs = pd.Series(cust_bal)

print(srs)

#assign index
srs_index = pd.Series(cust_bal, index = ["c1","c2","c3"])

print(srs_index)
# Out:
# Custumer-1    1000
# Custumer-2    1200
# Custumer-3    2500
# dtype: int64
# c1   NaN
# c2   NaN
# c3   NaN
# dtype: float64

# %% [markdown]
# **Locate Row**
#
# Pandas use the loc attribute to return one or more specified row(s)

# %%
import pandas as pd

data = {
    'comp_Brand' : ["Apple", "IBM", "Dell"],
     'product' : ["iPhone", "Computers", "Laptops"]
}

df = pd.DataFrame(data)

#refer to the row index:
print(df.loc[0])

print("\n\n Use a list of indexes:\n")

#use a list of indexes:
print(df.loc[[0,1]])


print("\n\n\n\n Named Indexes\n")


df = pd.DataFrame(data, index = ["d1","d2","d3"])
print(df)


print("\n\n\n Locate Named Indexes\n")

print(df.loc["d2"])
# Out:
# comp_Brand     Apple
# product       iPhone
# Name: 0, dtype: object
#
#
#  Use a list of indexes:
#
#   comp_Brand    product
# 0      Apple     iPhone
# 1        IBM  Computers
#
#
#
#
#  Named Indexes
#
#    comp_Brand    product
# d1      Apple     iPhone
# d2        IBM  Computers
# d3       Dell    Laptops
#
#
#
#  Locate Named Indexes
#
# comp_Brand          IBM
# product       Computers
# Name: d2, dtype: object

# %% [markdown]
# # **Section - 2 : Pandas - Working with the files(such as CSV and JSON)**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# **Load Files Into a DataFrame**
#
# If your data sets are stored in a file, Pandas can load them into a DataFrame.
# Load a comma separated file (CSV file) into a DataFrame:
#
# If you have a **large DataFrame** with many rows, Pandas will only ***return the first 5 rows, and the last 5 rows***

# %%
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Datafiles/data.csv')
#df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Datafiles/sales_data_sample.csv', sep=",", encoding='Latin-1')

print(df)
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data.csv', sep = ',', encoding = 'Latin-1')

print(df)
# Out:
#           Timestamp                    Email Address Title  \
# 0   2/28/2022 14:44       yogeshhathila046@gmail.com   Mr.
# 1   2/28/2022 14:58  bkchaudhary.civil@spcevng.ac.in   Mr.
# 2   2/28/2022 15:25   kesariyakaranvir0007@gmail.com   Mr.
# 3   2/28/2022 17:23      gosaisamarth2000@gmail.comg   Mr.
# 4    3/1/2022 14:30         utsavmaniyar07@gmail.com   Mr.
# ..              ...                              ...   ...
# 60  3/14/2022 11:42           ksdharva2003@gmail.com  Miss
# 61  3/14/2022 11:55       raj.sathavara122@gmail.com   Mr.
# 62  3/14/2022 11:55           pateldiya509@gmail.com  Miss
# 63  3/14/2022 11:55      rajputprashant319@gmail.com   Mr.
# 64     Offline Done       devsolanki384170@gmail.com  Miss
#
#    Name of the Applicant (to be printed on certificate)  Gender  \
# 0                            Hathila Yogesh Pankajbhi      Male
# 1                                     Bhanu chaudhary      Male
# ...

# %% [markdown]
# **to_string()** print the entire DataFrame.

# %%
print(df.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %% [markdown]
# **max_rows**
#
# The number of rows returned is ***defined in Pandas option settings***.
#
# You can **check your system's maximum rows** with the pd.options.display.max_rows statement.
#
# It shows 60 means If the DataFrame contains more than 60 rows, the print(df) statement will return only the headers and the first and last 5 rows.

# %%
import pandas as pd

print(pd.options.display.max_rows)
# Out:
# 60

# %% [markdown]
# Increase the maximum number of rows to display the entire DataFrame:

# %%
import pandas as pd

pd.options.display.max_rows = 999

df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Datafiles/data.csv')

print(df)
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %% [markdown]
# **Pandas Read JSON**
#
# Big data sets are often ***stored, or extracted as JSON***.
#
# JSON is **plain text**, but has the format of an object, and is well known in the world of programming, including Pandas.
#
# In our examples we will be using a JSON file called 'data.json'.
#
# ***JSON = Python Dictionary***
#
# JSON objects have the same format as Python dictionaries.

# %%
import pandas as pd

df = pd.read_json('/content/drive/MyDrive/Colab Notebooks/Datafiles/data.json')

print(df.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.5
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %% [markdown]
# If your JSON code is not in a file, but in a Python Dictionary, you can load it into a DataFrame directly:
#
# Load a Python Dictionary into a DataFrame:

# %%
import pandas as pd

data = {
  "Duration":{
    "0":60,
    "1":60,
    "2":60,
    "3":45,
    "4":45,
    "5":60
  },
  "Pulse":{
    "0":110,
    "1":117,
    "2":103,
    "3":109,
    "4":117,
    "5":102
  },
  "Maxpulse":{
    "0":130,
    "1":145,
    "2":135,
    "3":175,
    "4":148,
    "5":127
  },
  "Calories":{
    "0":409,
    "1":479,
    "2":340,
    "3":282,
    "4":406,
    "5":300
  }
}

df = pd.DataFrame(data)
print(df)
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130       409
# 1        60    117       145       479
# 2        60    103       135       340
# 3        45    109       175       282
# 4        45    117       148       406
# 5        60    102       127       300

# %% [markdown]
# # **Section - 3 : **Pandas - Analyzing DataFrames****

# %% [markdown]
# **Viewing the Data**
#
# One of the most used method for **getting a quick overview of the DataFrame, is the head()** method.
#
# The head() method returns the headers and a ***specified number of rows***, starting from the top.
#
#
# printing the first 10 rows of the DataFrame:

# %%
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Datafiles/data.csv')

print(df.head(10))
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0
# 5        60    102       127     300.0
# 6        60    110       136     374.0
# 7        45    104       134     253.3
# 8        30    109       133     195.1
# 9        60     98       124     269.0

# %% [markdown]
# if the number of **rows are not specified**, the head() method will return **the top 5 rows.**

# %%
print(df.head())
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0

# %% [markdown]
# Same Way the ***tail() method*** is used for viewing the ***last rows ***of the DataFrame.

# %%
print(df.tail())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4

# %% [markdown]
# **Info About the Data**
#
# It gives you more information about the data set.

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  6 non-null      int64
#  1   Pulse     6 non-null      int64
#  2   Maxpulse  6 non-null      int64
#  3   Calories  6 non-null      int64
# dtypes: int64(4)
# memory usage: 240.0+ bytes
# None

# %%
print(df.to_string())
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130       409
# 1        60    117       145       479
# 2        60    103       135       340
# 3        45    109       175       282
# 4        45    117       148       406
# 5        60    102       127       300

# %% [markdown]
# ⛔   **Null Values**
#
# The info() method also tells us how many Non-Null values there are present in each column, and in our data set it seems like there are 164 of 169 Non-Null values in the "Calories" column.
#
# Which means that there are 5 rows with no value at all, in the "Calories" column, for whatever reason.
#
# Empty values, or Null values, can be bad when analyzing data, and you should consider removing rows with empty values. This is a step towards what is called cleaning data, and you will learn more about that in the next chapters.

# %% [markdown]
# # **Section - 4 : Pandas - Data Cleaning**

# %% [markdown]
# Data cleaning means fixing bad data in your data set.
#
# Bad data could be:
#
# *   Empty cells
# *   Data in wrong format
# *   Wrong data
# *   Duplicates

# %%
import pandas as pd

e_data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Datafiles/erroneous_data.csv')

df = pd.DataFrame(e_data)

print(df)
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %% [markdown]
# The data set contains some empty cells ("Date" in row 22, and "Calories" in row 18 and 28).
#
# The data set contains wrong format ("Date" in row 26).
#
# The data set contains wrong data ("Duration" in row 7).
#
# The data set contains duplicates (row 11 and 12).

# %% [markdown]
# **Cleaning Empty Cells**
#
# Empty cells can potentially give you a wrong result when you analyze data.
#
# One way to deal with empty cells is **Remove Rows** which contain empty cells.
#
# If the data sets is having **huge records** then removing a few rows will not have a big impact on the result.

# %%
new_df = e_data.dropna() # This method returns a new DataFrame, and will not change the original.

print(new_df)
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %% [markdown]
# **If you want to change the original DataFrame, use the "inplace = True" argument:**

# %%
e_data.dropna(inplace=True) #It will NOT return a new DataFrame, but it will remove all rows containg NULL values from the original DataFrame.
print(e_data)
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %% [markdown]
# **Replace Empty Values**
#
# Another way of dealing with empty cells is to **insert a new value instead**.
#
# **Need not to delete entire rows** just because of some empty cells.
#
# The **fillna() method** allows us to replace empty cells with a value:

# %%
e_data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Datafiles/erroneous_data.csv')
e_data.fillna(130, inplace = True)
print(e_data)
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %% [markdown]
# **Replace Only For Specified Columns**
#
# Only replace empty values for one column, specify the column name for the DataFrame:

# %%
e_data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Datafiles/erroneous_data.csv')
e_data["Calories"].fillna(130, inplace = True)
print(e_data)
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %% [markdown]
# ***Still, Replacement of values are not justified.***
#
# ***So, What to do ?***
#
# 🤯     🤔

# %% [markdown]
# # **Section - 5 : Mean, Median and Mode**

# %% [markdown]
# **Replace Using Mean, Median, or Mode**
#
# A common way to replace empty cells, is to calculate the mean, median or mode value of the column.
#
# Pandas uses the ***mean()***, ***median()*** and ***mode()*** methods to calculate the respective values for a specified column

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Mean = the average value (the sum of all values divided by number of values).**
#
# *Calculate the MEAN, and replace any empty values with it:*

# %%
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Datafiles/erroneous_data.csv')

data = df["Calories"].mean()

df["Calories"].fillna(data, inplace = True)

print(df)
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130    409.10
# 1         60  '2020/12/02'    117       145    479.00
# 2         60  '2020/12/03'    103       135    340.00
# 3         45  '2020/12/04'    109       175    282.40
# 4         45  '2020/12/05'    117       148    406.00
# 5         60  '2020/12/06'    102       127    300.00
# 6         60  '2020/12/07'    110       136    374.00
# 7        450  '2020/12/08'    104       134    253.30
# 8         30  '2020/12/09'    109       133    195.10
# 9         60  '2020/12/10'     98       124    269.00
# 10        60  '2020/12/11'    103       147    329.30
# 11        60  '2020/12/12'    100       120    250.70
# 12        60  '2020/12/12'    100       120    250.70
# 13        60  '2020/12/13'    106       128    345.30
# 14        60  '2020/12/14'    104       132    379.30
# 15        60  '2020/12/15'     98       123    275.00
# ...

# %% [markdown]
# **Median = the value in the middle, after you have sorted all values ascending.**
#
# *Calculate the MEDIAN, and replace any empty values with it:*

# %%
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Datafiles/erroneous_data.csv')

data = df["Calories"].median()

df["Calories"].fillna(data, inplace = True)

print(df)
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %% [markdown]
# **Mode = the value that appears most frequently.**
#
# *Calculate the MODE, and replace any empty values with it:*

# %%
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Datafiles/erroneous_data.csv')

data = df["Calories"].mode()[0]

df["Calories"].fillna(data, inplace = True)

print(df)
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %% [markdown]
# **Data of Wrong Format**
#
# *Cells with data of wrong format can make it difficult, or even impossible, to analyze data.*
#
# To fix it, you have ***two options***:
# 1.   Remove the rows
# 2.   Convert all cells in the columns into the same format.
#
# ***Convert Into a Correct Format***
#
# To convert all cells in the **'Date'** column into dates, Pandas has a ***to_datetime()*** method for this:

# %%
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Datafiles/erroneous_data.csv')

df["Date"] = pd.to_datetime(df["Date"])

print(df.to_string)
# Out:
# <bound method DataFrame.to_string of     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01    110       130     409.1
# 1         60 2020-12-02    117       145     479.0
# 2         60 2020-12-03    103       135     340.0
# 3         45 2020-12-04    109       175     282.4
# 4         45 2020-12-05    117       148     406.0
# 5         60 2020-12-06    102       127     300.0
# 6         60 2020-12-07    110       136     374.0
# 7        450 2020-12-08    104       134     253.3
# 8         30 2020-12-09    109       133     195.1
# 9         60 2020-12-10     98       124     269.0
# 10        60 2020-12-11    103       147     329.3
# 11        60 2020-12-12    100       120     250.7
# 12        60 2020-12-12    100       120     250.7
# 13        60 2020-12-13    106       128     345.3
# 14        60 2020-12-14    104       132     379.3
# 15        60 2020-12-15     98       123     275.0
# 16        60 2020-12-16     98       120     215.2
# ...

# %% [markdown]
# **Removing Rows**

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Datafiles/erroneous_data.csv')

df.dropna(subset = ["Date"], inplace=True)

print(df)
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %% [markdown]
# ***Fixing Wrong Data***
#
# "Wrong data" does not have to be "empty cells" or "wrong format", it can just be wrong.
#
# **If you take a look at our data set, you can see that in row 7, the duration is 450, but for all the other rows the duration is between 30 and 60.**
#
# It doesn't have to be wrong, but taking in consideration that this is the data set of someone's workout sessions, we conclude with the fact that this person did not work out in 450 minutes.
#
# ***How can we fix wrong values, like the one for "Duration" in row 7?***
#
# ***Replacing Values***
#
# In our example, it is **most likely a typo**, and the value should be ***"45" instead of "450"***, and we could just insert "45" in row 7:

# %%
df.loc[7, 'Duration'] = 45

print(df)
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7         45  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %% [markdown]
# **For small data sets you might be able to replace the wrong data one by one, but not for big data sets.**
#
# To replace wrong data for larger data sets you can create some rules, e.g. set some boundaries for legal values, and replace any values that are outside of the boundaries.

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Datafiles/erroneous_data.csv')

for n in df.index:
  if df.loc[n, "Duration"] > 120:
    df.loc[n, "Duration"] = 120

print(df)
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        120  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %% [markdown]
# **Removing Rows** : Another way
#
# Delete rows where "Duration" is higher than 120:

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Datafiles/erroneous_data.csv')

for x in df.index:
  if df.loc[x, "Duration"] > 120:
    df.drop(x, inplace = True)

print(df)
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# 16        60  '2020/12/16'     98       120     215.2
# ...

# %% [markdown]
# **Removing Duplicates**
#
# Duplicate rows are rows that have been registered more than one time.
#
# In test data set, we can assume that row **11 and 12 are duplicates.**
#
# To discover duplicates, we can use the **duplicated()** method.
#
# The duplicated() method **returns a Boolean values (True/False)** for each row:

# %%
print(df.duplicated())
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12     True
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# dtype: bool

# %% [markdown]
# **Removing Duplicates**

# %%
df.drop_duplicates(inplace = True)
print(df)
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# 16        60  '2020/12/16'     98       120     215.2
# 17        60  '2020/12/17'    100       120     300.0
# ...

# %% [markdown]
# # **Section - 6 : Pandas - Data Correlations**

# %% [markdown]
# A great aspect of the Pandas module is the ***corr()*** method.
#
# The corr() method ***calculates the relationship between each column*** in your data set.
#
# ***Note: The corr() method ignores "not numeric" columns.***

# %%
df.corr()
# Out:
#           Duration     Pulse  Maxpulse  Calories
# Duration  1.000000 -0.059061 -0.239813  0.331283
# Pulse    -0.059061  1.000000  0.269752  0.512335
# Maxpulse -0.239813  0.269752  1.000000  0.360381
# Calories  0.331283  0.512335  0.360381  1.000000

# %% [markdown]
# ***Let's Discuss Result***
#
# The Result of the corr() method is a **table with a lot of numbers** that represents ***how well the relationship is between two columns***.
#
# **The number varies from -1 to 1.**
#
# ***1 means that there is a 1 to 1 relationship*** (a perfect correlation).
#
# ***The Correlation vaules and its behaviours...***
# *   1 is perfect, Each time a value went up in the first column, the other one went up as well.
# *   0.9 is also a good relationship, and if you increase one value, the other will probably increase as well.
# *   -0.9 would be just as good relationship as 0.9, but if you increase one value, the other will probably go down.
#
# *   0.2 means NOT a good relationship, meaning that if one value goes up does not mean that the other will.

# %% [markdown]
# ***What is a good correlation?***
#
# It depends on the use, but I think it is safe to say you have to have at least 0.6 (or -0.6) to call it a good correlation.

# %% [markdown]
# ***Perfect Correlation:***
# We can see that "Duration" and "Duration" got the number 1.000000, which makes sense, each column always has a perfect relationship with itself.
#
# ***Good Correlation:***
# "Duration" and "Calories" got a 0.922721 correlation, which is a very good correlation, and we can predict that the longer you work out, the more calories you burn, and the other way around: if you burned a lot of calories, you probably had a long work out.
#
# ***Bad Correlation:***
# "Duration" and "Maxpulse" got a 0.009403 correlation, which is a very bad correlation, meaning that we can not predict the max pulse by just looking at the duration of the work out, and vice versa.

# %% [markdown]
# # **Section - 7 : Pandas - Plotting**

# %% [markdown]
# Pandas uses the **plot()** method to create diagrams.
#
# We can use Pyplot, a submodule of the Matplotlib library to visualize the diagram on the screen.

# %%
import pandas as pd

import matplotlib.pyplot as plt

df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Datafiles/data.csv')

df.plot()

plt.show()

# %% [markdown]
# **Scatter Plot**
#
# Specify that you want a scatter plot with the kind argument:
#
# **kind = 'scatter'**
#
# A scatter plot needs an x- and a y-axis.

# %%
df.plot(kind='scatter', x='Duration', y='Calories')

plt.show()

# %%
df.plot(kind='scatter', x='Duration', y='Maxpulse')

plt.show()

# %% [markdown]
# **Histogram**
#
# Use the kind argument:
#
# **kind = 'hist'**
#
# ***A histogram needs only one column.***
#
# A histogram shows us the frequency of each interval

# %%
df['Duration'].plot(kind='hist')
plt.show()
